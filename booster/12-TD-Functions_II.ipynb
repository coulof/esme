# %% [markdown]
# <img style="margin-top: 0px" src=" data:image/png;base64,..." align="left" alt="logo esme"  height="20">
# <div class="alert alert-block alert-info" style="margin-top: 9px; padding: 10px; background: linear-gradient(to right, #f7f9fa, #d9edfb);">
#     <h1 style="margin-left: 85px">IngeSUP - TD 12 - Functions 2</h1>
# </div>

# %% [markdown]
# <blockquote><em>“Some men change party according to their opinions, others change opinion according to their party.”</em></blockquote>&nbsp;&nbsp;<i style="font-size: 10px">Winston Churchill</i>

# %% [markdown]
# ***
# ## Exercice 12.1 : Lists and functions
# ***

# %% [markdown]
# 1. Create a function called `Permuter()` which permutes two values in an array `T` passed as parameters. The indices `i` and `j` of the elements to be permuted must also be passed as parameters. The function will return the resulting array after the permutation.

# %%
# CODE HERE

# %% [markdown]
# 2. **Outside any function** create an array `tab` = [2,1,3] , then call your function with the array `tab`, `i` = 0 and `j` = 1. Display the result.

# %%
# CODE HERE

# %% [markdown]
# 3. Has the `T` array been modified by its call in the `Permuter()` function? Why or why not?

# %% [markdown]
# **Réponse:**
# Le tableau T a été modifié car il s'agit d'une liste. Quand on appelle une fonction sur une liste la fonction peut modifier la liste

# %% [markdown]
# ***
# ## Exercice 12.2 : Calculating the terms of a sequence defined by $u_n=f(n)$
# ***

# %% [markdown]
# Consider the sequence ($U_n$) defined for any natural number $n$ by
#
# $$u_n = \frac {3n-9}{2n+1}$$
#
# Create a function `U()` which takes as input a natural integer `n` and returns the value of $u_n$.

# %%
# CODE HERE

# %% [markdown]
# ***
# ## Exercice 12.3 : Calculating the terms of a sequence defined by recurrence
# ***

# %% [markdown]
# To use a program to calculate the terms of a sequence defined by recurrence, the idea is simply to calculate the values of the sequence as you go along, saving them in a single variable u starting at $u_0$.
#
# In the window below, we've already started writing a program to calculate the value of $u_n$.
# defined by $u_0=5$ et $u_{n+1}=2u_n−3$.
#
# Replace the **...** with whatever is necessary for the program to work.

# %%
# Replace the ... below with the appropriate code
# Don't forget: test your sequence on a few terms and check by hand...
# Watch out for indentation!

def suite_exo3(n):
    u0 = 5
    if n==0:
        return ...
    else:
        u_n = u0
        for i in range(1 ,n+1):
            u_n = ...
    return u_n

print(suite_exo3(6))
print(suite_exo3(4))
# Out:
# Ellipsis
# Ellipsis

# %% [markdown]
# ***
# ## Exercice 12.4 : Calculating the terms of a sequence defined by recurrence II
# ***

# %% [markdown]
# In this exercise, we consider a sequence $u$ defined by $u_{n+1}=3-4u_n$ and with first term $u_0$ (not indicated).
#
# The aim of this exercise is to create a program which takes as input the values of `n` and also `u_0` and displays the value of `u_n`.
#
# > Input : An integer `n` et `u_0`.
#
# > Output : The value of `u_n`.

# %%
def suite_exo4(n, u_0):
    if n==0:
        return ...
    else:
        u_n = u_0
        for i in range(... , ...):
            ...
        return ...
    
print(suite_exo4(2,1))

# %% [markdown]
# ***
# ## Exercice 12.5 : Approximate calculation of $\pi$
# ***

# %% [markdown]
# Leibniz's formula is an alternating series calculating an approximation of 𝜋 :
#
# <img src=" data:image/png;base64,...">

# %% [markdown]
# This series converges so slowly that nearly 200 terms are needed to calculate $\pi$ to two exact decimal places_!
#
# 1. Write a function to calculate an approximation of $\pi$ as a function of the desired number of terms $n$ ($n$ is a parameter of the function).

# %%
def leibniz(n):
    somme = 0
    for k in range(n+1):
        somme += ...
    return ...

print(leibniz(200))

# %% [markdown]
# 2. Using the previous function, write a function that calculates the approximation of $\pi$, so that the calculation stops when
#
# $|leibniz(K+1) - leibniz(K) | < 0.001$

# %%
def approximation():
    ...

approximation()

# %% [markdown]
# ***
# ## Exercice 12.6 : Approximate calculation of square roots
# ***

# %% [markdown]
# Consider the sequence defined by recurrence as follows :
#
#
# $$
# \left\{
#     \begin{array}{ll}
#           x_{0} = 2 \\
#           \forall n  \in \mathbb{N}, x_{n+1} = \frac {1}{2}(x_{n} + \frac {a}{x_n})
#     \end{array}
# \right.
# $$

# %% [markdown]
# 1. Program this numerical sequence. Your function will take two parameters: `n` which corresponds to the term of the sequence whose value we want, and `a` a constant specified by the user when calling the function.

# %%
def u(n,a):
    ...
    
print(u(1,2))

# %% [markdown]
# 2. Display the values of the first four terms of the sequence corresponding to `a` = 1.

# %%
# CODE HERE

# %% [markdown]
# _Héron's method evaluates the square root of a real A by progressively deforming a rectangle with an area equal to A_ :
#
# <img src=" data:image/png;base64,...">

# %% [markdown]
# 3. By modifying the previous sequence such that $x_0 = 1$ and $a=2$ we can obtain a good approximation of $\sqrt{2}$ by relying on **Héron's method**. Program this new sequence.

# %%
# CODE HERE

# %% [markdown]
# 4. From which term of the sequence do we have $|x_{k+1} - x_{k}| \le 0,001$ ?

# %%
# CODE HERE

# %% [markdown]
# ***
# ## Exercice 12.7 : Calculation of the terms of a sequence defined by double induction
# ***

# %% [markdown]
# Write a function `suite_exo7()` which calculates the n-th term of the sequence defined by:
#
# $$
# \left\{
#     \begin{array}{ll}
#           U_{1} = U_{2} = 1 \\
#           \forall n  \ge 3, U_{n+1} = 3U_{n-1} + 2U_{n-2}
#     \end{array}
# \right.
# $$

# %%
# CODE HERE

# %% [markdown]
# ***
# ## Exercice 12.8 : Arithmetic sum
# ***

# %% [markdown]
# Write an `arithmetic_sum()` function that calculates the value of the sum $1^p+2^p+3^p+⋯+n^p$ for values of `n` and $p$ given as parameters.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Exercice 12.9 : Average calculation
# ***

# %% [markdown]
# Write an `average()` function that calculates the average of the values in a `Tab` array given as a parameter.

# %%
# CODE HERE

# %% [markdown]
# ***
# ## Exercice 12.10 : Variance calculation
# ***

# %% [markdown]
# Using the `mean()` function, write a `variance()` function that calculates the variance of the values in an array `T` given as a parameter.
#
# **Note**: As a reminder, the calculation of the variance **_V_** of **_n_** values is performed with the **_mean m_** as follows:
#
# $$
# V(x) = \frac {1}{n} \sum_{i=0}^{n-1} (x_i - m)^2
# $$
#
# Here the $x_i$ represents the values in the table.

# %%
# CODE HERE

# %% [markdown]
# ***
# ## Answer for TD 12
#
# You can find the answer key for this TD [here](../Corrigés/Corrigé_TD%2012.ipynb).
