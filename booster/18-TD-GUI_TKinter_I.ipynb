# %% [markdown]
# <img style="margin-top: 0px" src=" data:image/png;base64,..." align="left" alt="logo esme"  height="20">
# <div class="alert alert-block alert-info" style="margin-top: 10px; padding: 10px; background: linear-gradient(to right, #f7f9fa, #d9edfb);">
#     <h1 style="margin-left: 85px">IngeSUP - TD 18 -  Graphical User Interface with TKinter 1 - First windows</h1>
# </div>

# %% [markdown]
# <blockquote><em>“If the door is closed, don't hesitate to use the window. ”</em></blockquote>&nbsp;&nbsp;<i style="font-size: 10px">Proverbe africain</i>

# %% [markdown]
# ***
# ## Exercise 01
# ***

# %% [markdown]
# Using the Tkinter Grid Layout widget management system, write a program in Tkinter Python that displays the following view:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="350">

# %% [markdown]
# ***
# ## Exercise 02
# ***

# %% [markdown]
# Improve the display of the dialog box from the previous exercise (Exercise1) by adding the parameters *width*, *padx* and *pady* to the buttons:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="350">

# %% [markdown]
# ***
# ## Exercise 03
# ***

# %% [markdown]
# Repeat the previous exercise (Exercise1) using the `place()` method:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="350">

# %% [markdown]
# ***
# ## Exercise 04
# ***

# %% [markdown]
# Write a program in python **_Tkinter_** that displays a window asking the user to enter his or her name and displaying a welcome message:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="350">

# %% [markdown]
# ***
# ## Exercise 05
# ***

# %% [markdown]
# Write a script to display a data insertion form in a **_tkinter_** window, organized as shown in the figure below:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="350">

# %% [markdown]
# ***
# ## Exercise 06
# ***

# %% [markdown]
# The incomplete program below defines a minimalist graphical interface containing a text box and two buttons **_launch_** and **_Quit_**. Only the **_Quit_** button is active.
#
# 1. The **launch** button calls the `launch()` function. Complete this function so that the variable result takes the value of a random integer between 1 and 6.
#
#
# 2. The `launch()` function must also modify the display of the *display_text* zone so that the value of result appears there. **Roll** the die several times to start "playing".

# %%
##-----Import Modules-----##
from tkinter import *

##-----Define Tunctions-----##
def lancer():
    """ Inputs: Button-triggered function - no inputs
		Outputs: Simulates the roll of a 6-sided die and displays the result in the text box."""
    result = 0
    ...

##-----Create Window----##
fen = Tk()
fen.title('Launch a dice')

##-----Create Button-----##
launch_button = Button(fen, text='Launch', command=lancer)
launch_button.grid(row = 1, column = 0, padx=5, pady=3)

quit_button = Button(fen, text='Quit', command=fen.destroy)
quit_button.grid(row = 1, column = 1, padx = 5, pady = 3)

##-----Create Text zone-----##
display_text = Label(fen, text='')
display_text.grid(row = 0, column = 0, columnspan = 2)

##-----Main loop to wait for events-----##
fen.mainloop()

# %% [markdown]
# 3. What is the purpose of the `fen.destroy` command?

# %% [markdown]
# **Answer:**
