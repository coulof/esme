# %% [markdown]
# <img style="margin-top: 0px" src=" data:image/png;base64,..." align="left" alt="logo esme"  height="20">
# <div class="alert alert-block alert-info" style="margin-top: 10px; padding: 10px; background: linear-gradient(to right, #f7f9fa, #d9edfb);">
#     <h1 style="margin-left: 85px">IngeSUP - TD 20 - Interface graphique avec TKinter 3 - Une pluie de widgets </h1>
# </div>

# %% [markdown]
# <blockquote><em>“Tous ces moments se perdront dans l'oubli, comme des larmes dans la pluie.”</em></blockquote>&nbsp;&nbsp;<i style="font-size: 10px">Blade Runner - Personnage inconnu</i>

# %% [markdown]
# ***
# ## Exercice 01
# ***

# %% [markdown]
# En s'inspirant du script du cours, écrire une application avec interface graphique qui calcule la racine carrée d'un nombre.
#
# Par exemple, le calcul de √3 donne :

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %% [markdown]
# <b><u>Remarque:</u></b> Pour obtenir le résultat ci-dessus, on a rentré la valur 3 et on cliqué sur "Calculer".

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Exercice 02
# ***

# %% [markdown]
# Reprendre le script de mot de passe du cours de manière à limiter le nombre d'essais à trois maximum.

# %% [markdown]
# <img src=" data:image/png;base64,..." width="400">

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Exercice 03
# ***

# %% [markdown]
# Ecrire une application avec interface graphique *tkinter* qui calcule l'addition ou la soustraction de deux nombres :

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Exercice 04
# ***

# %% [markdown]
#  Reprendre le script du cours qui dessine une cible et remplacer le disque noir par une image :

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
# VOTRE CODE ICI

# %% [markdown]
# <b><u>Remarque:</u></b> Un fichier nommé <b>impact.gif</b> se trouve sur Moodle.

# %% [markdown]
# ***
# ## Exercice 05
# ***

# %% [markdown]
# Ecrire un script qui tire une carte et l'affiche à une position aléatoire comme dans le *Canvas* ci-dessous :

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
# VOTRE CODE ICI

# %% [markdown]
# <b><u>Note:</u></b> Télécharger les images des 52 cartes et un squelette du script sur Moodle

# %% [markdown]
# ***
# ## Corrigé du TD 20
#
# Vous pouvez retrouver le corrigé de ce TD [ici](../Corrigés/Corrigé_TD%2020.ipynb).
