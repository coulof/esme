# %% [markdown]
# <img style="margin-top: 0px" src=" data:image/png;base64,..." align="left" alt="logo esme"  height="20">
# <div class="alert alert-block alert-info" style="margin-top: 10px; padding: 10px; background: linear-gradient(to right, #f7f9fa, #d9edfb);">
#     <h1 style="margin-left: 85px">IngeSUP - Cours 20 - Graphical User Interface with TKinter 3 - It's raining widgets !</h1>
# </div>

# %% [markdown]
# <div style='color: rgb(49, 112, 143)'>
#     <h3>Summary</h3>
# </div>

# %% [markdown]
# Python's Tkinter ("Tk interface") module lets you create graphical user interfaces (GUIs).
#
# Numerous graphical components (or widgets) are available. You're already familiar with some of them: window (*Tk*), button (*Button*), label (*Label*), simple text area (*Entry*), graphical area (*Canvas*), while others are still to be discovered: checkbox (*Checkbutton*), menu (*Menu*), graphical area (*Canvas*), frame (*Frame*) and many more are to be found in the [documentation](https://docs.python.org/3/library/tk.html) 📚

# %% [markdown]
# We're going to learn how to manipulate new widgets through **real-life use cases**. The aim of this session is to familiarize you with the use of new Widgets by adapting code already supplied, while getting you used to searching for information.

# %% [markdown]
# <div class="alert alert-block alert-info" style='color:white; background-color:blue; border-color: blue; '>
#     <h2>Some useful widgets and use cases</h2>
# </div>

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Button & Label</h3>
# </div>

# %% [markdown]
# <img src=" data:image/png;base64,..." width="200">

# %%
from tkinter import *

# Main window creation
window = Tk()

# Creation of a Label widget (text 'Hello World !')
Label1 = Label(window, text = 'Hello World !', fg = 'red')
# Positionnement du widget avec la méthode pack()
Label1.pack()

# Creation of a Button widget (button Quit)
button1 = Button(window, text = 'Quit', command = window.destroy)
button1.pack()

# Launching the event manager
window.mainloop()

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Button & Label 2</h3>
# </div>

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
from tkinter import *
import random

def NouveauLance():
    nb = random.randint(1,6)
    Texte.set('Résultat -> ' + str(nb))

# Création de la fenêtre principale (main window)
Mafenetre = Tk()

Mafenetre.title('Dé à 6 faces')
Mafenetre.geometry('300x100+400+400')

# Création d'un widget Button (bouton Lancer)
BoutonLancer = Button(Mafenetre, text ='Lancer', command = NouveauLance)
# Positionnement du widget avec la méthode pack()
BoutonLancer.pack(side = LEFT, padx = 5, pady = 5)

# Création d'un widget Button (bouton Quitter)
BoutonQuitter = Button(Mafenetre, text ='Quitter', command = Mafenetre.destroy)
BoutonQuitter.pack(side = LEFT, padx = 5, pady = 5)

Texte = StringVar()
NouveauLance()

# Création d'un widget Label (texte 'Résultat -> x')
LabelResultat = Label(Mafenetre, textvariable = Texte, fg ='red', bg ='white')
LabelResultat.pack(side = LEFT, padx = 5, pady = 5)

Mafenetre.mainloop()

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Frame, Label & Button</h3>
# </div>

# %% [markdown]
# <img src=" data:image/png;base64,..." width="350">

# %%
from tkinter import *


window = Tk()
window.title('Frame widget')
window['bg']='bisque'

# create a Frame widget in the main window
Frame1 = Frame(window,borderwidth=2,relief=GROOVE)
Frame1.pack(side=LEFT,padx=10,pady=10)

# create a second Frame widget in the main window
Frame2 = Frame(window,borderwidth=2,relief=GROOVE)
Frame2.pack(side=LEFT,padx=10,pady=10)

# creating a Frame widget... within a Frame widget
# Frame1 widget is the parent of Frame3 widget
# the parent of Frame1 widget is the window widget (main window)
Frame3 = Frame(Frame1,bg="white",borderwidth=2,relief=GROOVE)
Frame3.pack(side=LEFT,padx=10,pady=10)

# creating a Label widget and a Button widget in a Frame widget
Label(Frame1,text="Dentist appointment at 3pm").pack(padx=10,pady=10)
Button(Frame1,text="Remove",fg='navy',command=Frame1.destroy).pack(padx=10,pady=10)

Label(Frame2,text="Revision for Computer Science exam").pack(padx=10,pady=10)
Button(Frame2,text="Remove",fg='navy',command=Frame2.destroy).pack(padx=10,pady=10)

Label(Frame3,text="entist appointment at 10am",bg="white").pack(padx=10,pady=10)
Button(Frame3,text="Remove",fg='navy',command=Frame3.destroy).pack(padx=10,pady=10)

window.mainloop()

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Entry, Label, Button & MessageBox</h3>
# </div>

# %% [markdown]
# <img src=" data:image/png;base64,..." width="380">

# %%
from tkinter import *
from tkinter.messagebox import * # boîte de dialogue

def Verify():
    if Password.get() == 'python27':
        # le mot de passe est bon : on affiche une boîte de dialogue puis on ferme la fenêtre
        showinfo('Result','Correct password.\nBye !')
        window.destroy()
    else:
        # le mot de passe est incorrect : on affiche une boîte de dialogue
        showwarning('Result','Wrong password.\nTry again !')
        Password.set('')

# Création de la fenêtre principale (main window)
window = Tk()
window.title('Identification requise')

# Création d'un widget Label (texte 'Mot de passe')
Label1 = Label(window, text = 'Mot de passe ')
Label1.pack(side = LEFT, padx = 5, pady = 5)

# Création d'un widget Entry (champ de saisie)
Password= StringVar()
Champ = Entry(window, textvariable= Password, show='*', bg ='bisque', fg='maroon')
Champ.focus_set()
Champ.pack(side = LEFT, padx = 5, pady = 5)

# Création d'un widget Button (bouton Valider)
Bouton = Button(window, text ='Valider', command = Verify)
Bouton.pack(side = LEFT, padx = 5, pady = 5)

window.mainloop()

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Spinbox & Label</h3>
# </div>

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
from tkinter import *

def square():
    """ Square calculation """
    Resultat.set("Square = "+str(float(value.get())**2))

# Création de la fenêtre principale (main window)
window = Tk()
window.title("Spinbox widget")

value = StringVar()
value.set(2.0)
# Création d'un widget Spinbox
boite = Spinbox(window,from_=0,to=10,increment=0.5,textvariable=value,width=5,command=square)
boite.pack(padx=30,pady=10)

# Création d'un widget Label
Resultat = StringVar()
square()
Label(window,textvariable=Resultat).pack(padx=30,pady=10)

window.mainloop()

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Scale & Button</h3>
# </div>

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
from tkinter import *

def maj(newvalue):
    # nouvelle valeur en argument
    print(newvalue)
def plus():
    Valeur.set(str(int(Valeur.get())+10))
    print(Valeur.get())
def minus():
    Valeur.set(str(int(Valeur.get())-10))
    print(Valeur.get())

# Création de la fenêtre principale (main window)
window = Tk()
window.title("Scale widget")

Valeur = StringVar()
Valeur.set(50)
# Création d'un widget Scale
echelle = Scale(window,from_=-100,to=100,resolution=10,orient=HORIZONTAL, length=300,width=20,label="Offset",tickinterval=20,variable=Valeur,command=maj)
echelle.pack(padx=10,pady=10)

# Création d'un widget Button (bouton +)
Button(window,text="+",command=plus).pack(padx=10,pady=10)

# Création d'un widget Button (bouton -)
Button(window,text="-",command=minus).pack(padx=10,pady=10)

window.mainloop()
# Out:
# 60
# 70
# 80
# 70
# 60
# 50
# 40
# 30
# 20
# 10
# 0

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Canvas & Button</h3>
# </div>

# %% [markdown]
# Each time the Go button is clicked, the script draws a disk with a radius of 20 pixels at a random position:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
from tkinter import *
import random

def Circle():
    """ Draw a circle with center (x,y) and radius r """
    x = random.randint(0,Largeur)
    y = random.randint(0,Hauteur)
    r = 20
    canvas.create_oval(x-r, y-r, x+r, y+r, outline='blue', fill='blue')

def Effacer():
    """ Efface la zone graphique """
    canvas.delete(ALL)

# Create main window
window = Tk()
window.title('Circle')

# Create Canvas
Largeur = 480
Hauteur = 320
canvas = Canvas(window, width = Largeur, height =Hauteur, bg ='white')
canvas.pack(padx =5, pady =5)

# Create Button Go
BoutonGo = Button(window, text ='Go', command = Circle)
BoutonGo.pack(side = LEFT, padx = 10, pady = 10)

# Create Button Erase
ButtonErase = Button(window, text ='Erase', command = Effacer)
ButtonErase.pack(side = LEFT, padx = 5, pady = 5)

# Create Button Quitter
ButtonQuit = Button(window, text ='Quit', command = window.destroy)
ButtonQuit.pack(side = LEFT, padx = 5, pady = 5)

window.mainloop()

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Canvas & Button : Image management</h3>
# </div>

# %% [markdown]
# <img src=" data:image/jpeg;base64,..." width="300">

# %%
from tkinter import *
import random

def Circle():
    """ Draw a circle with center (x,y) and radius r """
    x = random.randint(0,Width)
    y = random.randint(0,Height)
    r = 10
    
    # Draw a circle in the Canvas
    item = Canvas.create_oval(x-r, y-r, x+r, y+r, outline='black', fill='black')
    
    print("Création du cercle (item" , item ,")")

    print(Canvas.find_all())

def Undo():
    """ Efface le dernier cercle"""
    if len(Canvas.find_all()) > 1:
        item = Canvas.find_all()[-1]
        # Remove the circle
        Canvas.delete(item)
       
        print("Suppression du cercle (item" , item ,")")
        print(Canvas.find_all())

def EreaseAll():
    """ Erease all circles"""
    while len(Canvas.find_all()) > 1:
        Undo()


# Création de la fenêtre principale (main window)
Window = Tk()
Window.title('Cible')

# Image de fond
photo = PhotoImage(file="tk_cible.gif")

# Création d'un widget Canvas (zone graphique)
Width = 550
Height = 550
Canvas1 = Canvas(Window,width = Width, height =Height)
item = Canvas1.create_image(0,0,anchor=NW, image=photo)
print("Image de fond (item",item,")")
Canvas1.pack()

# Création d'un widget Button
BoutonGo = Button(Window, text ='Go', command = Circle)
BoutonGo.pack(side = LEFT, padx = 10, pady = 10)

# Création d'un widget Button
ButtonErease = Button(Window, text ='Erease Last shot', command = Undo)
ButtonErease.pack(side = LEFT, padx = 10, pady = 10)

# Création d'un widget Button
ButtonEreaseAll = Button(Window, text ='Erease All', command = EreaseAll)
ButtonEreaseAll.pack(side = LEFT, padx = 10, pady = 10)

# Création d'un widget Button (bouton Quitter)
ButtonQuit = Button(Window, text ='Quit', command = Window.destroy)
ButtonQuit.pack(side = LEFT, padx = 10, pady = 10)

Window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[8], line 38
#      35 Window.title('Cible')
#      37 # Image de fond
# ---> 38 photo = PhotoImage(file="tk_cible.gif")
#      40 # Création d'un widget Canvas (zone graphique)
#      41 Width = 550
#
# File c:\Program Files\Python310\lib\tkinter\__init__.py:4093, in PhotoImage.__init__(self, name, cnf, master, **kw)
#    4088 def __init__(self, name=None, cnf={}, master=None, **kw):
#    4089     """Create an image with NAME.
#    4090
#    4091     Valid resource names: data, format, file, gamma, height, palette,
#    4092     width."""
# -> 4093     Image.__init__(self, 'photo', name, cnf, master, **kw)
#
# File c:\Program Files\Python310\lib\tkinter\__init__.py:4038, in Image.__init__(self, imgtype, name, cnf, master, **kw)
#    4036         v = self._register(v)
#    4037     options = options + ('-'+k, v)
# ...

# %% [markdown]
# 💾 L'image de fond **_tk_cible.gif_** est à télécharger sur Moodle

# %% [markdown]
# <div style='color: forestgreen'>
#    <h3>Widgets Menu & Canvas ; image management ; dialog boxes FileDialog & MessageBox</h3>
# </div>

# %% [markdown]
# The following script is an image browser (formats .gif .ppm .pgm), with a Menu widget :

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %% [markdown]
# A FileDialog dialog box to search for a file :

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %% [markdown]
# and a Canvas widget in which to display the image:

# %% [markdown]
# <img src=" data:image/png;base64,..." width="300">

# %%
from tkinter import *
import tkinter.messagebox
import tkinter.filedialog

def Ouvrir():
    Canevas.delete(ALL) # on efface la zone graphique

    filename = tkinter.filedialog.askopenfilename(title="Ouvrir une image",filetypes=[('gif files','.gif'),('all files','.*')])
    print(filename)

    photo = PhotoImage(file=filename)
    gifdict[filename] = photo  # référence
    print(gifdict)

    Canevas.create_image(0,0,anchor=NW,image=photo)
    Canevas.config(height=photo.height(),width=photo.width())

    Mafenetre.title("Image "+str(photo.width())+" x "+str(photo.height()))

def Fermer():
    Canevas.delete(ALL)
    Mafenetre.title("Image")

def Apropos():
    tkinter.messagebox.showinfo("A propos","Tutorial Python Tkinter\n(C) Fabrice Sincère")

# Main window
Mafenetre = Tk()
Mafenetre.title("Image")

# Création d'un widget Menu
menubar = Menu(Mafenetre)

menufichier = Menu(menubar,tearoff=0)
menufichier.add_command(label="Ouvrir une image",command=Ouvrir)
menufichier.add_command(label="Fermer l'image",command=Fermer)
menufichier.add_command(label="Quitter",command=Mafenetre.destroy)
menubar.add_cascade(label="Fichier", menu=menufichier)

menuaide = Menu(menubar,tearoff=0)
menuaide.add_command(label="A propos",command=Apropos)
menubar.add_cascade(label="Aide", menu=menuaide)

# Affichage du menu
Mafenetre.config(menu=menubar)

# Création d'un widget Canvas
Canevas = Canvas(Mafenetre)
Canevas.pack(padx=5,pady=5)

# Utilisation d'un dictionnaire pour conserver une référence
gifdict={}

Mafenetre.mainloop()
