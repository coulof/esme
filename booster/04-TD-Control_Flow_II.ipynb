# %% [markdown]
# <img style="margin-top: 0px" src=" data:image/png;base64,..." align="left" alt="logo esme"  height="20">
# <div class="alert alert-block alert-info" style="margin-top: 9px; padding: 10px; background: linear-gradient(to right, #f7f9fa, #d9edfb);">
#     <h1 style="margin-left: 85px">IngeSUP - TD 04 - Les structures conditionnelles II</h1>
# </div>

# %% [markdown]
# <blockquote><em>“Il y'a deux manières d'écrire un programme sans erreur. Seule la troisième marche”</em></blockquote>&nbsp;&nbsp;<i style="font-size: 10px">Alan J. Perlis</i>

# %% [markdown]
# ***
# ## Exercice 04.1
# ***

# %% [markdown]
# L'aide personnalisée au logement (APL) est une aide financière destinée principalement à réduire le montant d'un
# loyer. Le but de cet exercice est de concevoir un simulateur simplifié de droits à l'APL pour les locataires.
#
# Afin de déterminer le montant de l'APL auquel une personne a droit, la Caisse d'Allocations Familiales (CAF) retient
# un plafond maximum de ressources et un plafond maximum de loyer qui sert de base au calcul des droits selon
# le lieu de résidence et la composition de la famille.

# %% [markdown]
# Si votre loyer dépasse les plafonds appliqués par la CAF, le supplément n'est pas pris en compte pour le calcul de l'APL. On suppose que le plafond du revenu annuel de référence du foyer est de 16000 euros. Le lieu de résidence est découpé en 3 zones :
#
# - Zone 1 : Ile de France
# - Zone 2 : Villes de plus de 100000 habitants
# - Zone 3 : Toutes les autres villes
#
# Voici les plafonds des loyers APL pris en compte en fonction de la zone géographique du logement :
#
# **Composition du foyer**       | **Zone 1** | **Zone 2** | **Zone 3**
# ---------  | ---------  | ---------  | ---------
# Personne seule | 295,85 EUR | 257,14 EUR |241,00 EUR |
# Couple     |  355,85 EUR | 314,74 EUR |292,16 EUR |
# Personne seule ou couple avec personne à charge |  402,18 EUR | 354,17 EUR |327,59 EUR |
# Personne supplémentaire    |  58,34 EUR | 51,54 EUR | 46,95 EUR |
#
# À ce montant il faut soustraire un montant fixe qui reste à votre charge et qui est fixé à 34,76 euros.
#
# **Exemple** : Une célibataire résidant en Île-de-France pourra toucher un montant APL maximum de 258,09 euros
# (292,85 - 34,76), quel que soit le montant de son loyer (hormis si son loyer est inférieur, elle touchera alors un montant APL
# correspondant à l'intégralité de son loyer).

# %% [markdown]
# - Ecrire un programme python qui :
#     - Demande à l'utilisateur le revenu annuel de référence de son foyer dans une variable `revenu`.
#
#     - Demande à l'utilisateur s'il habite en ile de france puis dans le cas contraite le nombre d'habitants de sa ville.
#
#     - Détermine la zone d'habitation de l'utilisateur selon ce qui a été saisi à la question précédente, dans une variable `zone`.
#
#     - Demande à l'utilisateur si la personne est seule ou en couple.
#
#     - Demande à l'utilisateur si elle a des personnes à charge et si oui combien de personnes sont à sa charge.
#
#     - Demande à l'utilisateur le montant de son loyer et stockez le résultat dans une variable `loyer`.
#
#     - Calcule et affiche le montant de l'APL reçu et le montant restant du loyer à payer. Vos stockerez ces données dans des variables respectivement nommées `APL` et `restant`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Exercice 04.2
# ***

# %% [markdown]
# On souhaite écrire un programme qui calcule la fréquence de passage de trains dans la Ville de Koh-Lantin sur Orge en Essonne. Voici comment la régie des transports a organisé le trafic:
#
# - Le week-end, le train passe toutes les 30 minutes.
#
# - En semaine, il passe toutes les 20 minutes en heures creuses et toutes les 10 minutes en heures d'affluence. Les heures d'affluences sont entre 7h et 10h (inclus) et entre 17h et 19h (inclus).
#
# Ecrivez un programme qui demande à l'utilisateur un jour (sous forme de chaîne de caractères) et une heure (de 0 à 23) et qui affiche la fréquence correspondante sous la forme d'une phrase : "La fréquence est d'un train toutes les n minutes" (n étant soit 10, soit 20 soit 30).
#
# On supposera que l'utilisatrice entre toujours une réponse qui a du sens.

# %%
# VOTRE CODE ICI

# %% [markdown]
# <hr><h2>Exercice 04.3 - Nombre de jours du mois</h2><hr>
#     <ol>
#   <li>
#     <p>Ecrivez un programme qui affiche le  nombre de jours d'un mois entré par l'utilisateur (en toutes lettres minuscules).<br>
#
# Le nombre total de jours dans un mois est donné par le tableau ci-dessous.<br>
#    </p>
#        <p><img src=" data:image/png;base64,...">
#     </p>
#     <p>
#     La sortie pourrait ressembler à :
#
#     Entrez un mois : janvier
#     Le mois de janvier compte 31 jours
#
#    PS: Pour le mois de février on se contentera dire qu'il compte 28 ou 29 jours pour l'instant...
#     </p>
#   </li>
#    </ol>
#  </div>

# %%
# VOTRE CODE ICI

# %% [markdown]
# <hr><h2>Exercice 04.4 - Je peux pas j'ai piscine</h2><hr>
#     <ul>
#         On souhaite écrire un programme qui calcule le tarif d'une entrée à la piscine municipale de la ville. Voici comment le conseil municipal a organisé ses tarifs :
#             <ul>
#                 <li style="margin-top: 12px; margin-bottom: 12px">Le week-end, la piscine coûte 3,50 € pour les adultes et 2 € pour les enfants (12 ans et moins) et ce, toute la journée.</li>
#
#   <li style="margin-top: 12px; margin-bottom: 12px">En semaine, la piscine a les tarifs réduits en heures creuses : 2 € pour tout le monde. Cependant elle coûte 3 € pour les adultes et 2 € pour les enfants end en heures d'affluence. Les heures d'affluences sont entre 10h et 13h (inclus) et entre 17h et 20h (inclus).</li>
#             </ul>
#     </ul>
# <p>Ecrivez un programme qui demande à l'utilisateur son âge, le jour de la semaine (sous forme de chaîne de caractères) et une heure (de 0 à 23) et donne le tarif correspondant sous la forme d'une phrase : "Le tarif que vous paierez est de n €" (n étant soit 2, soit 3 soit 3.50).</p>
#
# <p>On supposera que l'utilisateur entre toujours une réponse qui a du sens.</p>

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Corrigé du TD 04
#
# Vous pouvez retrouver le corrigé de ce TD [ici](../Corrigés/Corrigé_TD%2004.ipynb).
